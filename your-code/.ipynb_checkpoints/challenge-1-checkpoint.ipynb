# %% [markdown]
# ## Before you start :
#    - These exercises are related to the Exploratory data analysis using matplotlib and seaborn.
#    - The datasets for Challenge 2 and 3 are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# # Challenge 1

# %% [markdown]
# Answer all questions by drawing a graph. Then explain.

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

import datetime

# %% [markdown]
# **0. Load seaborn dataset "tips"**

# %%
df = sns.load_dataset("tips")


df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# **1. What is the prefered day for eating?**

# %%
df['day'].value_counts() #saturday
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
sns.displot(df.day,
            #facecolor ='navajowhite',
            edgecolor = "black",
            bins = 4, 
            height = 6,
            aspect = 2);

# %% [markdown]
# **2. What days of the week has more men than women payers?**

# %%
df1 = df[df['sex'] == 'Female']


df2 = df[df['sex'] == 'Male']

# %%
df1['day'].value_counts()
# Out:
# Thur    32
# Sat     28
# Sun     18
# Fri      9
# Name: day, dtype: int64

# %%
df2['day'].value_counts() # las chicas prefieren los juernes
# Out:
# Sat     59
# Sun     58
# Thur    30
# Fri     10
# Name: day, dtype: int64

# %%
# seaborn.displot(data=None, *, x=None, y=None, hue=None, row=None, 
# col=None, weights=None, kind='hist', rug=False, rug_kws=None, log_scale=None, 
# legend=True, palette=None, hue_order=None, hue_norm=None, color=None, col_wrap=None, 
# row_order=None, col_order=None, height=5, aspect=1, facet_kws=None, **kwargs)

# %%
# método 1:

sns.displot(df,
            x = 'day',
            hue = 'sex',
            edgecolor = "black", # poner el color de la línea 
            bins = 4, 
            height = 6, # establecer la altura de la gráfica
            aspect = 2); # establecer la relación del aspecto

# %%
# método 2:

df11 = df.groupby(['day', 'sex']).count()['size'].reset_index()

df11.columns = ['Day', 'Sex', 'Count']

sns.barplot(df11, 
            x = 'Day', 
            y = 'Count',
            hue = 'Sex')
# Out:
# <Axes: xlabel='Day', ylabel='Count'>

# %%
df11
# Out:
#     Day     Sex  Count
# 0  Thur    Male     30
# 1  Thur  Female     32
# 2   Fri    Male     10
# 3   Fri  Female      9
# 4   Sat    Male     59
# 5   Sat  Female     28
# 6   Sun    Male     58
# 7   Sun  Female     18

# %% [markdown]
# **3. Do you think bill amounts change considerably depending on smoking?**

# %%
df3 = df[df['smoker'] == 'Yes']



df4 = df[df['smoker'] == 'No']

# %%
df6 = pd.DataFrame()


df6['total_bill'] = pd.cut(df3['total_bill'], 5)


# smokers cortada en 4 intervalos

df6['total_bill'].value_counts()
# Out:
# (12.618, 22.166]    41
# (22.166, 31.714]    21
# (3.022, 12.618]     17
# (31.714, 41.262]    10
# (41.262, 50.81]      4
# Name: total_bill, dtype: int64

# %%
df7 = pd.DataFrame()


df7['total_bill'] = pd.cut(df4['total_bill'], 4)


# non smokers cortada en 4 intervalos

df7['total_bill'].value_counts()
# Out:
# (7.209, 17.52]    75
# (17.52, 27.79]    56
# (27.79, 38.06]    14
# (38.06, 48.33]     6
# Name: total_bill, dtype: int64

# %%
# método 1:

sns.displot(df,
            x = 'total_bill',
            hue = 'smoker',
            edgecolor = "black", # poner el color de la línea 
            bins = 4, 
            height = 6, # establecer la altura de la gráfica
            aspect = 2); # establecer la relación del aspecto

# %%
# los fumadores no gastan más en las bills porque ya pagan suficiente al estado

# %%
# método 2:

df12 = df.groupby(['smoker']).sum('total_bill').reset_index() 


sns.barplot(df12, 
            x = 'smoker',
            y = 'total_bill')
# Out:
# <Axes: xlabel='smoker', ylabel='total_bill'>

# %%
# método 3:

sns.kdeplot(x = df.total_bill,
            hue = df.smoker)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# **4. Is tip correlated to total_bill? Draw a scatter plot**

# %%
# Plot data and a linear regression model fit.

# también sns.lmplot

ax = sns.regplot(df,
            x = "total_bill",
            y = "tip")

ax.set_title("Correlation between total bill and tip")
ax.set_xlabel("Total bill");
ax.set_ylabel("Tip");

# %%
# Correlation between two columns of DataFrame.

df['tip'].corr(df['total_bill'])
# Out:
# 0.6757341092113641

# %%
from scipy import stats

# Pearson’s r , p-value (probability that the true value of r is zero)

stats.pearsonr(df['total_bill'], df['tip'])
# Out:
# PearsonRResult(statistic=0.6757341092113647, pvalue=6.6924706468630016e-34)

# %%
# Sí, están relacionadas. Como se puede observar a medida que aumenta total_tip, aumenta la tip con una relación de 1-0,65

# %% [markdown]
# **BONUS**: Draw a graph of your choice with 2 numerical variables and 2 categorical variable (HINT: use `hue` and `style`). Do you find it useful?

# %%
sns.scatterplot(x=df.total_bill, y=df.tip, hue=df.sex, style=df.time, data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# No es demasiado useful visualizar las variables de esta manera

# %%
sns.relplot(df, x="total_bill", y="tip", hue="day", col="time")

# %%
g = sns.FacetGrid(df, col="time",  row="sex")
g.map(sns.scatterplot, "total_bill", "tip")

# %%
g = sns.FacetGrid(df, col="time", hue="sex")
g.map_dataframe(sns.scatterplot, x="total_bill", y="tip")
g.add_legend()
